# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Using-Dictionaries" data-toc-modified-id="Using-Dictionaries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Using Dictionaries</a></span></li><li><span><a href="#Using-a-DataFrame" data-toc-modified-id="Using-a-DataFrame-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Using a DataFrame</a></span><ul class="toc-item"><li><span><a href="#Examining-winning-agent" data-toc-modified-id="Examining-winning-agent-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Examining winning agent</a></span><ul class="toc-item"><li><span><a href="#Keeping-Informations-about-the-competing-agent" data-toc-modified-id="Keeping-Informations-about-the-competing-agent-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Keeping Informations about the competing agent</a></span></li><li><span><a href="#Considering-just-winning-agent" data-toc-modified-id="Considering-just-winning-agent-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Considering just winning agent</a></span></li></ul></li></ul></li><li><span><a href="#Data-Visualization" data-toc-modified-id="Data-Visualization-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data Visualization</a></span></li></ul></div>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import operator
pd.set_option('display.max_columns', 50)
pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv('15-11-2019_1330_all_genius_agents_party_domain.csv',';', skiprows=1) 
df.head()
# Out:
#    Run time (s)  Round Exception  deadline Agreement Discounted  #agreeing  \
# 0         0.035     30       NaN  60rounds       Yes         No          2
# 1         0.006     10       NaN  60rounds       Yes         No          2
# 2         0.002      3       NaN  60rounds       Yes         No          2
# 3         0.036     56       NaN  60rounds       Yes         No          2
# 4         0.028     46       NaN  60rounds       Yes         No          2
#
#    min.util.  max.util.  Dist. to Pareto  Dist. to Nash  Social Welfare  \
# 0    0.49465    0.97500          0.00000        0.47369         1.46965
# 1    0.65833    1.00000          0.00000        0.14542         1.65833
# 2    0.65833    1.00000          0.00000        0.14542         1.65833
# 3    0.49083    0.50455          0.43045        0.51607         0.99538
# 4    0.56667    0.82423          0.19823        0.24198         1.39090
#
#                                 Agent 1                     Agent 2  \
# 0            BoulwareNegotiationParty@0  ConcederNegotiationParty@1
# 1            ConcederNegotiationParty@2  BoulwareNegotiationParty@3
# 2                         SimpleAgent@4  BoulwareNegotiationParty@5
# 3  RandomCounterOfferNegotiationParty@6  BoulwareNegotiationParty@7
# 4                         RandomParty@8  BoulwareNegotiationParty@9
#
#    Utility 1  Utility 2  Disc. Util. 1  Disc. Util. 2  Perceived. Util. 1  \
# 0   0.975000   0.494647       0.975000       0.494647            0.975000
# 1   0.658333   1.000000       0.658333       1.000000            0.658333
# 2   0.658333   1.000000       0.658333       1.000000            0.000000
# 3   0.490833   0.504546       0.490833       0.504546            0.490833
# 4   0.566667   0.824234       0.566667       0.824234            0.566667
#
#    Perceived. Util. 2  User Bother 1  User Bother 2  User Util. 1  \
# 0            0.494647            0.0            0.0      0.975000
# 1            1.000000            0.0            0.0      0.658333
# 2            1.000000            0.0            0.0      0.658333
# 3            0.504546            0.0            0.0      0.490833
# 4            0.824234            0.0            0.0      0.566667
#
#    User Util. 2           Profile 1           Profile 2
# 0      0.494647  party1_utility.xml  party2_utility.xml
# 1      1.000000  party1_utility.xml  party2_utility.xml
# 2      1.000000  party1_utility.xml  party2_utility.xml
# 3      0.504546  party1_utility.xml  party2_utility.xml
# 4      0.824234  party1_utility.xml  party2_utility.xml

# %%
for i in range(0, df.shape[0]):
    df['Agent 1'][i] = df['Agent 1'][i].split('@', 1)[0]
    df['Agent 2'][i] = df['Agent 2'][i].split('@', 1)[0]

df.head(7)
# Out:
#    Run time (s)  Round Exception  deadline Agreement Discounted  #agreeing  \
# 0         0.035     30       NaN  60rounds       Yes         No          2
# 1         0.006     10       NaN  60rounds       Yes         No          2
# 2         0.002      3       NaN  60rounds       Yes         No          2
# 3         0.036     56       NaN  60rounds       Yes         No          2
# 4         0.028     46       NaN  60rounds       Yes         No          2
# 5         0.033     54       NaN  60rounds       Yes         No          2
# 6         0.039     53       NaN  60rounds       Yes         No          2
#
#    min.util.  max.util.  Dist. to Pareto  Dist. to Nash  Social Welfare  \
# 0    0.49465    0.97500          0.00000        0.47369         1.46965
# 1    0.65833    1.00000          0.00000        0.14542         1.65833
# 2    0.65833    1.00000          0.00000        0.14542         1.65833
# 3    0.49083    0.50455          0.43045        0.51607         0.99538
# 4    0.56667    0.82423          0.19823        0.24198         1.39090
# 5    0.70874    0.81833          0.06688        0.22234         1.52708
# 6    0.63008    0.71500          0.17546        0.30658         1.34508
#
#                               Agent 1                   Agent 2  Utility 1  \
# 0            BoulwareNegotiationParty  ConcederNegotiationParty   0.975000
# 1            ConcederNegotiationParty  BoulwareNegotiationParty   0.658333
# 2                         SimpleAgent  BoulwareNegotiationParty   0.658333
# 3  RandomCounterOfferNegotiationParty  BoulwareNegotiationParty   0.490833
# 4                         RandomParty  BoulwareNegotiationParty   0.566667
# 5                        RandomParty2  BoulwareNegotiationParty   0.818333
# 6                              AgentF  BoulwareNegotiationParty   0.715000
#
#    Utility 2  Disc. Util. 1  Disc. Util. 2  Perceived. Util. 1  \
# 0   0.494647       0.975000       0.494647            0.975000
# 1   1.000000       0.658333       1.000000            0.658333
# 2   1.000000       0.658333       1.000000            0.000000
# 3   0.504546       0.490833       0.504546            0.490833
# 4   0.824234       0.566667       0.824234            0.566667
# 5   0.708742       0.818333       0.708742            0.818333
# 6   0.630081       0.715000       0.630081            0.715000
#
#    Perceived. Util. 2  User Bother 1  User Bother 2  User Util. 1  \
# 0            0.494647            0.0            0.0      0.975000
# 1            1.000000            0.0            0.0      0.658333
# 2            1.000000            0.0            0.0      0.658333
# 3            0.504546            0.0            0.0      0.490833
# 4            0.824234            0.0            0.0      0.566667
# 5            0.708742            0.0            0.0      0.818333
# 6            0.630081            0.0            0.0      0.715000
#
#    User Util. 2           Profile 1           Profile 2
# 0      0.494647  party1_utility.xml  party2_utility.xml
# 1      1.000000  party1_utility.xml  party2_utility.xml
# 2      1.000000  party1_utility.xml  party2_utility.xml
# 3      0.504546  party1_utility.xml  party2_utility.xml
# 4      0.824234  party1_utility.xml  party2_utility.xml
# 5      0.708742  party1_utility.xml  party2_utility.xml
# 6      0.630081  party1_utility.xml  party2_utility.xml

# %%
df['Agent 1'].value_counts()
# Out:
# SimpleAgent       224
# PhoenixParty      112
# OMACagent         112
# MeanBot           112
# MetaAgent2013     112
#                  ...
# AgentYK           112
# DrageKnight       112
# WhaleAgent        112
# FuzzyAgent        112
# ClockworkAgent    112
# Name: Agent 1, Length: 112, dtype: int64

# %%
df['Agent 2'].value_counts()
# Out:
# SimpleAgent       224
# PhoenixParty      112
# OMACagent         112
# MeanBot           112
# MetaAgent2013     112
#                  ...
# AgentYK           112
# DrageKnight       112
# WhaleAgent        112
# FuzzyAgent        112
# ClockworkAgent    112
# Name: Agent 2, Length: 112, dtype: int64

# %%
print(df.shape)
percent_missing = df.isnull().sum() * 100 / len(df)
missing_values = pd.DataFrame({'percent_missing': percent_missing})
missing_values.sort_values(by ='percent_missing' , ascending=False)[0:3]
# Out:
# (12656, 26)
#               percent_missing
# Exception           80.783818
# Run time (s)        19.216182
# User Util. 2        19.216182

# %%
df = df.drop('Exception', axis=1).dropna()
df = df.reset_index()

# %%
df['Agent 1'].value_counts()
# Out:
# SimpleAgent             204
# Ngent                   104
# UtilityBasedAcceptor    104
# Farma                   103
# BRAMAgent2              103
#                        ...
# XianFaAgent              94
# JonnyBlack               63
# OptimalBidderSimple      59
# FuzzyAgent               56
# Rubick                    4
# Name: Agent 1, Length: 102, dtype: int64

# %%
df['Agent 1'].value_counts()
# Out:
# SimpleAgent             204
# Ngent                   104
# UtilityBasedAcceptor    104
# Farma                   103
# BRAMAgent2              103
#                        ...
# XianFaAgent              94
# JonnyBlack               63
# OptimalBidderSimple      59
# FuzzyAgent               56
# Rubick                    4
# Name: Agent 1, Length: 102, dtype: int64

# %% [markdown]
# ## Using Dictionaries

# %%
agents = np.unique(np.append(df['Agent 1'].unique(), df['Agent 2'].unique()))

evalDict = {}
for i in range(0, len(agents)):
    evalDict[agents[i]] = [0]

for i in range(0, df.shape[0]):
    evalDict[df['Agent 1'][i]] += df['Utility 1'][i]
    evalDict[df['Agent 2'][i]] += df['Utility 2'][i]
    
sorted(evalDict.items(), key=operator.itemgetter(1), reverse=True)
# Out:
# [('SimpleAgent', array([234.08602929])),
#  ('DoNA', array([155.97340518])),
#  ('NiceTitForTat', array([155.5707146])),
#  ('TheNegotiator', array([154.47273237])),
#  ('Terra', array([154.3810536])),
#  ('PokerFace', array([153.12712336])),
#  ('BraveCat', array([152.933796])),
#  ('Yushu', array([152.77225769])),
#  ('BRAMAgent', array([152.70448308])),
#  ('AgentBuyogMain', array([152.29407027])),
#  ('Atlas32016', array([150.6521839])),
#  ('Atlas3', array([150.22062676])),
#  ('SENGOKU', array([149.80270984])),
#  ('Group2', array([149.48997416])),
#  ('AgentF', array([149.43508742])),
#  ('TMFAgent', array([149.12139333])),
#  ('ParsCat', array([146.9961564])),
#  ('GrandmaAgent', array([146.76936058])),
#  ('RandomDance', array([145.51715555])),
#  ('TimeDependentAgentBoulware', array([145.10909733])),
#  ('AgentHP2_main', array([145.00061781])),
#  ('DrageKnight', array([144.20309104])),
#  ('BoulwareNegotiationParty', array([144.13097401])),
#  ('AgentQuest', array([143.87736085])),
#  ('AgentYK', array([142.93131883])),
#  ('Farma', array([142.50548131])),
#  ('FunctionalAcceptor', array([142.39759007])),
#  ('AgentLight', array([141.65367862])),
#  ('MetaAgent2013', array([141.52855973])),
#  ('IAMhaggler2011', array([141.19834678])),
#  ('AgentW', array([140.90026973])),
#  ('Flinch', array([140.78614495])),
#  ('AgentHP', array([139.47387709])),
#  ('MyAgent', array([139.34516271])),
#  ('Caduceus', array([139.22406371])),
#  ('ParsAgent', array([138.3591763])),
#  ('MeanBot', array([137.95165834])),
#  ('Simpatico', array([137.55541013])),
#  ('AgentKF', array([137.33312351])),
#  ('Mercury', array([136.77707947])),
#  ('PNegotiator', array([136.27043246])),
#  ('IAMhaggler', array([135.91990589])),
#  ('ClockworkAgent', array([135.67939533])),
#  ('TUDMixedStrategyAgent', array([135.62577272])),
#  ('TimeDependentAgentLinear', array([135.59894483])),
#  ('Nozomi', array([134.18536431])),
#  ('Agent_K2', array([133.92073879])),
#  ('AgentSmith', array([133.90543552])),
#  ('Agent_K', array([132.68567334])),
#  ('MetaAgent', array([132.50104041])),
#  ('InoxAgent', array([132.48709635])),
#  ('IAMhaggler2012', array([131.37459851])),
#  ('ABMPAgent2', array([128.93019154])),
#  ('ValueModelAgent', array([128.46686116])),
#  ('TimeDependentAgentConceder', array([127.27708927])),
#  ('AgentI', array([127.14873037])),
#  ('ConcederNegotiationParty', array([127.06451041])),
#  ('BayesianAgent', array([126.94747785])),
#  ('IAMcrazyHaggler', array([126.11923487])),
#  ('kawaii', array([125.86382831])),
#  ('AgentMR', array([125.69195017])),
#  ('SimilarityAgent', array([123.64946798])),
#  ('ParsAgent2', array([122.39935594])),
#  ('AgentTD', array([121.83880033])),
#  ('TheFawkes', array([121.36348536])),
#  ('AgentFSEGA', array([119.95524334])),
#  ('AgentH', array([119.51170239])),
#  ('AgentX', array([118.04116739])),
#  ('PonPokoAgent', array([117.27180816])),
#  ('OMACagent', array([115.70226449])),
#  ('Groupn', array([115.48044655])),
#  ('UtilityBasedAcceptor', array([112.44971557])),
#  ('TheNegotiatorReloaded', array([111.42578491])),
#  ('AgentLG', array([110.94587121])),
#  ('RandomParty2', array([108.22372903])),
#  ('SlavaAgent', array([107.86650575])),
#  ('SYAgent', array([107.81457929])),
#  ('YXAgent', array([106.80487007])),
#  ('CUHKAgent', array([106.73052578])),
#  ('KLH', array([106.38093063])),
#  ('RandomCounterOfferNegotiationParty', array([106.22495372])),
#  ('RandomParty', array([105.86887884])),
#  ('AgentTRP', array([105.80162346])),
#  ('AresParty', array([105.78226989])),
#  ('PhoenixParty', array([102.5972533])),
#  ('Gahboninho', array([102.49357972])),
#  ('ImmediateAcceptor', array([100.66152369])),
#  ('AgentM', array([100.52881888])),
#  ('WhaleAgent', array([100.45198671])),
#  ('Sobut', array([95.97667746])),
#  ('BRAMAgent2', array([95.])),
#  ('TimeDependentAgentHardliner', array([94.])),
#  ('CUHKAgent2015', array([92.48009141])),
#  ('MaxOops', array([85.55119699])),
#  ('XianFaAgent', array([84.])),
#  ('Gangster', array([81.71015373])),
#  ('AgentSmith2016', array([76.80035774])),
#  ('Ngent', array([60.81064151])),
#  ('AnacSampleAgent', array([33.28220268])),
#  ('Atlas', array([32.69685959])),
#  ('JonnyBlack', array([24.37452182])),
#  ('Rubick', array([9.])),
#  ('Aster', array([1.])),
#  ('FuzzyAgent', array([0.])),
#  ('OptimalBidderSimple', array([0.]))]

# %%
agents = np.unique(np.append(df['Agent 1'].unique(), df['Agent 2'].unique()))

evalDict2 = {} 
for i in range(0, len(agents)):
    evalDict2[agents[i]] = 0

for i in range(0, df.shape[0]):
    if df['Utility 1'][i] > df['Utility 2'][i]:
        evalDict2[df['Agent 1'][i]] += 1
    elif df['Utility 1'][i] < df['Utility 2'][i]:
        evalDict2[df['Agent 2'][i]] += 1
    else:
        evalDict2[df['Agent 1'][i]] += 0
        evalDict2[df['Agent 2'][i]] += 0
    
sorted(evalDict2.items(), key=operator.itemgetter(1), reverse=True)
# Out:
# [('SimpleAgent', 135),
#  ('AgentFSEGA', 134),
#  ('PNegotiator', 130),
#  ('AgentMR', 127),
#  ('ValueModelAgent', 127),
#  ('kawaii', 127),
#  ('Nozomi', 125),
#  ('PokerFace', 123),
#  ('NiceTitForTat', 122),
#  ('Groupn', 120),
#  ('PonPokoAgent', 120),
#  ('OMACagent', 119),
#  ('InoxAgent', 118),
#  ('ParsAgent2', 117),
#  ('Simpatico', 117),
#  ('IAMcrazyHaggler', 116),
#  ('Terra', 116),
#  ('TheNegotiatorReloaded', 116),
#  ('AgentLG', 115),
#  ('YXAgent', 115),
#  ('AgentBuyogMain', 112),
#  ('MetaAgent', 111),
#  ('SlavaAgent', 111),
#  ('BRAMAgent', 110),
#  ('CUHKAgent', 110),
#  ('KLH', 110),
#  ('SYAgent', 110),
#  ('AresParty', 109),
#  ('BraveCat', 108),
#  ('Caduceus', 106),
#  ('MetaAgent2013', 105),
#  ('ParsAgent', 104),
#  ('Gahboninho', 103),
#  ('Mercury', 103),
#  ('TheNegotiator', 101),
#  ('DrageKnight', 100),
#  ('Flinch', 100),
#  ('AgentKF', 98),
#  ('DoNA', 97),
#  ('Farma', 96),
#  ('MaxOops', 96),
#  ('BRAMAgent2', 95),
#  ('BayesianAgent', 95),
#  ('Sobut', 95),
#  ('AgentLight', 94),
#  ('MeanBot', 94),
#  ('TimeDependentAgentHardliner', 94),
#  ('Yushu', 94),
#  ('AgentQuest', 93),
#  ('Atlas32016', 92),
#  ('IAMhaggler', 90),
#  ('Group2', 89),
#  ('AgentI', 88),
#  ('ClockworkAgent', 88),
#  ('RandomDance', 88),
#  ('TMFAgent', 87),
#  ('Agent_K2', 85),
#  ('FunctionalAcceptor', 85),
#  ('AgentF', 84),
#  ('Agent_K', 84),
#  ('XianFaAgent', 84),
#  ('AgentHP', 83),
#  ('ParsCat', 83),
#  ('SENGOKU', 79),
#  ('AgentHP2_main', 78),
#  ('TheFawkes', 76),
#  ('Atlas3', 72),
#  ('TimeDependentAgentBoulware', 71),
#  ('IAMhaggler2011', 70),
#  ('PhoenixParty', 68),
#  ('BoulwareNegotiationParty', 66),
#  ('AgentSmith', 63),
#  ('AgentW', 62),
#  ('CUHKAgent2015', 62),
#  ('IAMhaggler2012', 62),
#  ('AgentYK', 57),
#  ('TimeDependentAgentLinear', 55),
#  ('MyAgent', 54),
#  ('GrandmaAgent', 53),
#  ('ABMPAgent2', 46),
#  ('AgentTD', 45),
#  ('TUDMixedStrategyAgent', 42),
#  ('Gangster', 38),
#  ('Ngent', 37),
#  ('SimilarityAgent', 37),
#  ('ConcederNegotiationParty', 34),
#  ('TimeDependentAgentConceder', 30),
#  ('AgentH', 29),
#  ('AgentSmith2016', 26),
#  ('JonnyBlack', 25),
#  ('AgentX', 23),
#  ('UtilityBasedAcceptor', 23),
#  ('RandomParty2', 21),
#  ('AgentTRP', 19),
#  ('RandomParty', 16),
#  ('AgentM', 15),
#  ('RandomCounterOfferNegotiationParty', 14),
#  ('WhaleAgent', 13),
#  ('ImmediateAcceptor', 12),
#  ('Rubick', 9),
#  ('Aster', 1),
#  ('Atlas', 1),
#  ('AnacSampleAgent', 0),
#  ('FuzzyAgent', 0),
#  ('OptimalBidderSimple', 0)]

# %% [markdown]
# ## Using a DataFrame

# %%
agents = np.unique(np.append(df['Agent 1'].unique(), df['Agent 2'].unique()))

data = {'Agents Name': agents, 'Overall Utility': np.zeros(len(agents)), 'Total Dist to Nash': np.zeros(len(agents))} 

final_df = pd.DataFrame(data= data)

for i in range(0, df.shape[0]):
    final_df['Overall Utility'][final_df['Agents Name'] == df['Agent 1'][i]] += df['Utility 1'][i]
    final_df['Overall Utility'][final_df['Agents Name'] == df['Agent 2'][i]] += df['Utility 2'][i]
    final_df['Total Dist to Nash'][final_df['Agents Name'] == df['Agent 1'][i]] += df['Dist. to Nash'][i]
    final_df['Total Dist to Nash'][final_df['Agents Name'] == df['Agent 2'][i]] += df['Dist. to Nash'][i]

    
final_df.sort_values(by ='Total Dist to Nash' , ascending=True)
# Out:
#                     Agents Name  Overall Utility  Total Dist to Nash
# 25                        Aster         1.000000             0.14542
# 80                       Rubick         9.000000             4.61194
# 90                        Terra       154.381054            45.66660
# 92                TheNegotiator       154.472732            48.19372
# 81                      SENGOKU       149.802710            49.05016
# ..                          ...              ...                 ...
# 45                   Gahboninho       102.493580           159.24763
# 30                   BRAMAgent2        95.000000           167.22258
# 64                        Ngent        60.810642           168.20872
# 96  TimeDependentAgentHardliner        94.000000           168.81489
# 85                  SimpleAgent       234.086029           183.47882
#
# [105 rows x 3 columns]

# %%
# evalDict2 = {'Agents Name': agents, 'Matches Win': np.zeros(len(agents))} 

# evalDict2 = pd.DataFrame(data=evalDict2)

final_df['Matches Win'] = np.zeros(len(agents))
final_df['N Matches'] = np.zeros(len(agents))

for i in range(0, df.shape[0]):
    if df['Utility 1'][i] > df['Utility 2'][i]:
        final_df['Matches Win'][final_df['Agents Name'] == df['Agent 1'][i]] += 1
    elif df['Utility 1'][i] < df['Utility 2'][i]:
        final_df['Matches Win'][final_df['Agents Name'] == df['Agent 2'][i]] += 1
    else:
        final_df['Matches Win'][final_df['Agents Name'] == df['Agent 1'][i]] += 0
        final_df['Matches Win'][final_df['Agents Name'] == df['Agent 2'][i]] += 0
    final_df['N Matches'][final_df['Agents Name'] == df['Agent 1'][i]] += 1
    final_df['N Matches'][final_df['Agents Name'] == df['Agent 2'][i]] += 1

final_df = final_df[final_df['N Matches'] > 99]
final_df.sort_values(by ='N Matches' , ascending=True)
# Out:
#              Agents Name  Overall Utility  Total Dist to Nash  Matches Win  \
# 23       AnacSampleAgent        33.282203            63.05191          0.0
# 26                 Atlas        32.696860            63.49998          1.0
# 44            FuzzyAgent         0.000000           138.61488          0.0
# 56            JonnyBlack        24.374522           118.78393         25.0
# 68   OptimalBidderSimple         0.000000           148.34224          0.0
# ..                   ...              ...                 ...          ...
# 86            SlavaAgent       107.866506           144.03675        111.0
# 46              Gangster        81.710154           131.28216         38.0
# 50       IAMcrazyHaggler       126.119235           103.85461        116.0
# 104               kawaii       125.863828           108.48928        127.0
# 85           SimpleAgent       234.086029           183.47882        135.0
#
#      N Matches
# 23       100.0
# 26       100.0
# 44       114.0
# 56       115.0
# 68       122.0
# ..         ...
# 86       204.0
# 46       204.0
# 50       204.0
# 104      204.0
# 85       403.0
#
# [103 rows x 5 columns]

# %%
final_df['Matches Win'][final_df['Agents Name'] == 'JonnyBlack']
# Out:
# 56    25.0
# Name: Matches Win, dtype: float64

# %%
# final_df = final_df[final_df['N Matches'] > 99]
# final_df.sort_values(by ='N Matches' , ascending=True)

# %%
final_df = final_df[final_df['N Matches'] < 240]
final_df.sort_values(by ='Total Dist to Nash' , ascending=True) #[0:]
# Out:
#                     Agents Name  Overall Utility  Total Dist to Nash  \
# 90                        Terra       154.381054            45.66660
# 92                TheNegotiator       154.472732            48.19372
# 81                      SENGOKU       149.802710            49.05016
# 74                    PokerFace       153.127123            49.35438
# 48                       Group2       149.489974            50.55537
# ..                          ...              ...                 ...
# 87                        Sobut        95.976677           158.56268
# 45                   Gahboninho       102.493580           159.24763
# 30                   BRAMAgent2        95.000000           167.22258
# 64                        Ngent        60.810642           168.20872
# 96  TimeDependentAgentHardliner        94.000000           168.81489
#
#     Matches Win  N Matches
# 90        116.0      198.0
# 92        101.0      198.0
# 81         79.0      200.0
# 74        123.0      196.0
# 48         89.0      200.0
# ..          ...        ...
# 87         95.0      203.0
# 45        103.0      204.0
# 30         95.0      204.0
# 64         37.0      201.0
# 96         94.0      204.0
#
# [102 rows x 5 columns]

# %%
final_df.sort_values(by ='N Matches' , ascending=False)
# Out:
#              Agents Name  Overall Utility  Total Dist to Nash  Matches Win  \
# 104               kawaii       125.863828           108.48928        127.0
# 12               AgentMR       125.691950           118.38504        127.0
# 41                 Farma       142.505481            75.26113         96.0
# 45            Gahboninho       102.493580           159.24763        103.0
# 46              Gangster        81.710154           131.28216         38.0
# ..                   ...              ...                 ...          ...
# 68   OptimalBidderSimple         0.000000           148.34224          0.0
# 56            JonnyBlack        24.374522           118.78393         25.0
# 44            FuzzyAgent         0.000000           138.61488          0.0
# 23       AnacSampleAgent        33.282203            63.05191          0.0
# 26                 Atlas        32.696860            63.49998          1.0
#
#      N Matches
# 104      204.0
# 12       204.0
# 41       204.0
# 45       204.0
# 46       204.0
# ..         ...
# 68       122.0
# 56       115.0
# 44       114.0
# 23       100.0
# 26       100.0
#
# [102 rows x 5 columns]

# %%
final_df.sort_values(by ='Overall Utility' , ascending=False)[:1]['Agents Name'].values
# Out:
# array(['DoNA'], dtype=object)

# %% [markdown]
# ### Examining winning agent

# %% [markdown]
# #### Keeping Informations about the competing agent

# %%
def agent_focus(agent_name):
    one = df[df['Agent 1'] == agent_name] 
    two = df[df['Agent 2'] == agent_name]
    result = pd.concat([one, two])
    return result

result = agent_focus('Atlas32016')

# %%
result.Agreement.value_counts()
# Out:
# Yes    196
# No       6
# Name: Agreement, dtype: int64

# %%
np.mean(result['Dist. to Nash'])
# Out:
# 0.27629514851485143

# %% [markdown]
# #### Considering just winning agent

# %%
def single_agent_focus(agent_name):
    one = df[df['Agent 1'] == agent_name] 
    two = df[df['Agent 2'] == agent_name]
    #print(one.head())
    one = one.drop(["Agent 2", "Utility 2","Disc. Util. 2", "Perceived. Util. 2",
                    "User Bother 2", "User Util. 2", "Profile 2"], axis=1)
    two = two.drop(["Agent 1", "Utility 1","Disc. Util. 1", "Perceived. Util. 1",
                    "User Bother 1", "User Util. 1", "Profile 1"], axis=1)
    two = two.rename(columns={"Agent 2" : "Agent 1", "Utility 2": "Utility 1",
                              "Disc. Util. 2": "Disc. Util. 1", "Perceived. Util. 2": "Perceived. Util. 1",
                              "User Bother 2" : "User Bother 1", "User Util. 2": "User Util. 1", 
                              "Profile 2": "Profile 1"})
    result = pd.concat([one, two])
    return result

result = single_agent_focus('Atlas32016')
result
# Out:
#       index  Run time (s)  Round  deadline Agreement Discounted  #agreeing  \
# 11       16         0.036     53  60rounds       Yes         No          2
# 112     129         0.021     33  60rounds       Yes         No          2
# 213     242         0.003      4  60rounds       Yes         No          2
# 314     355         0.022     36  60rounds       Yes         No          2
# 413     468         0.025     36  60rounds       Yes         No          2
# ...     ...           ...    ...       ...       ...        ...        ...
# 1206   1916         0.002      3  60rounds       Yes         No          2
# 1207   1917         0.041     61  60rounds        No         No          1
# 1208   1918         0.032     50  60rounds       Yes         No          2
# 1209   1919         0.649     39  60rounds       Yes         No          2
# 1210   1920         0.024     22  60rounds       Yes         No          2
#
#       min.util.  max.util.  Dist. to Pareto  Dist. to Nash  Social Welfare  \
# 11      0.63008    0.71500          0.17546        0.30658         1.34508
# 112     0.46849    0.96667          0.02746        0.49465         1.43515
# 213     0.29693    1.00000          0.00000        0.66723         1.29693
# 314     0.50299    0.76417          0.21100        0.42609         1.26716
# 413     0.45437    0.75333          0.22530        0.47525         1.20770
# ...         ...        ...              ...            ...             ...
# 1206    0.65833    1.00000          0.00000        0.14542         1.65833
# 1207    0.00000    0.00000          1.03604        1.21592         0.00000
# 1208    0.74562    0.80250          0.07619        0.18378         1.54812
# 1209    0.68493    0.88167          0.00000        0.26211         1.56660
# 1210    0.72167    0.95238          0.02381        0.06766         1.67404
#
#          Agent 1  Utility 1  Disc. Util. 1  Perceived. Util. 1  User Bother 1  \
# 11    Atlas32016   0.715000       0.715000            0.715000            0.0
# 112   Atlas32016   0.966667       0.966667            0.966667            0.0
# 213   Atlas32016   1.000000       1.000000            1.000000            0.0
# 314   Atlas32016   0.764167       0.764167            0.764167            0.0
# 413   Atlas32016   0.753333       0.753333            0.753333            0.0
# ...          ...        ...            ...                 ...            ...
# 1206  Atlas32016   1.000000       1.000000            1.000000            0.0
# 1207  Atlas32016   0.000000       0.000000            0.000000            0.0
# 1208  Atlas32016   0.745617       0.745617            0.745617            0.0
# 1209  Atlas32016   0.684930       0.684930            0.684930            0.0
# 1210  Atlas32016   0.952377       0.952377            0.952377            0.0
#
#       User Util. 1           Profile 1
# 11        0.715000  party1_utility.xml
# 112       0.966667  party1_utility.xml
# 213       1.000000  party1_utility.xml
# 314       0.764167  party1_utility.xml
# 413       0.753333  party1_utility.xml
# ...            ...                 ...
# 1206      1.000000  party2_utility.xml
# 1207      0.000000  party2_utility.xml
# 1208      0.745617  party2_utility.xml
# 1209      0.684930  party2_utility.xml
# 1210      0.952377  party2_utility.xml
#
# [202 rows x 19 columns]

# %%
np.mean(result['Utility 1']), np.mean(result['User Util. 1']), np.mean(result['Perceived. Util. 1'])
# Out:
# (0.7458028905739181, 0.7458028905739181, 0.7458028905739181)

# %% [markdown]
# ## Data Visualization

# %%
#for i in df.columns:
    #plt.figure(i)
    #sns.countplot(x = i,data = df,hue = i)
    #print(i)
    #print(df[i].value_counts(), '\n')

# %%
def dist_plot(agent_name, distance):
    score = {}
    for i in range(0, df.shape[0]):
        if df['Agent 1'][i] == agent_name:
            try:
                score[df['Agent 2'][i]].append(df[distance][i])
            except KeyError:
                score[df['Agent 2'][i]] = []
                score[df['Agent 2'][i]].append(df[distance][i])
        elif df['Agent 2'][i] == agent_name:
            try:
                score[df['Agent 1'][i]].append(df[distance][i])
            except KeyError:
                score[df['Agent 1'][i]] = []
                score[df['Agent 1'][i]].append(df[distance][i])

    #print(score)

    plot_opp = []
    plot_dist = []
    for i in score.keys():
        plot_opp.append(i)
        plot_dist.append(np.mean(score[i]))

    print(agent_name + " mean " + distance + ": " + str(np.mean([x for x in plot_dist if str(x) != 'nan'])))
    figure(num=None, figsize=(22, 10), dpi=80, facecolor='w', edgecolor='k')
    plt.title(distance + " for " + agent_name + "(Mean :" + str(np.mean([x for x in plot_dist if str(x) != 'nan'])) + ")", 
              fontsize=18)
    plt.xticks(fontsize=18, rotation=60)
    plt.yticks(fontsize=18)
    plt.plot(plot_opp, plot_dist)

# %%
dist_plot(final_df.sort_values(by ='Overall Utility' , ascending=False)[:1]['Agents Name'].values, 'Dist. to Nash')
# Out:
# ['DoNA mean Dist. to Nash: 0.28156485294117645']

# %%
dist_plot('JonnyBlack', 'Dist. to Nash')
# Out:
# JonnyBlack mean Dist. to Nash: 1.0089420454545457

# %%
dist_plot('IAMhaggler2011', 'Dist. to Nash')
# Out:
# IAMhaggler2011 mean Dist. to Nash: 0.2982063970588235

# %%
dist_plot('Agent_K', 'Dist. to Nash')
# Out:
# Agent_K mean Dist. to Nash: 0.4030530000000001

# %%
dist_plot('Gahboninho', 'Dist. to Pareto')
# Out:
# Gahboninho mean Dist. to Pareto: 0.5086547549019608

# %%
dist_plot('Gahboninho', 'Social Welfare')
# Out:
# Gahboninho mean Social Welfare: 0.7702304411764707
